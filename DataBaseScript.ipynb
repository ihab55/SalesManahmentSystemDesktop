-- %% [markdown]
-- # [SSTOREONLINE]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SSTOREONLINE]    Script Date: 4/19/2026 2:36:31 PM ******/
CREATE DATABASE [SSTOREONLINE]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SSTOREONLINE', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SSTOREONLINE.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SSTOREONLINE_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SSTOREONLINE_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SSTOREONLINE] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SSTOREONLINE].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SSTOREONLINE] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET ARITHABORT OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SSTOREONLINE] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SSTOREONLINE] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET  ENABLE_BROKER 
GO
ALTER DATABASE [SSTOREONLINE] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SSTOREONLINE] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET RECOVERY FULL 
GO
ALTER DATABASE [SSTOREONLINE] SET  MULTI_USER 
GO
ALTER DATABASE [SSTOREONLINE] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SSTOREONLINE] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SSTOREONLINE] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SSTOREONLINE] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SSTOREONLINE] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SSTOREONLINE] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'SSTOREONLINE', N'ON'
GO
ALTER DATABASE [SSTOREONLINE] SET QUERY_STORE = ON
GO
ALTER DATABASE [SSTOREONLINE] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[CATEGORYS]

-- %%
USE [SSTOREONLINE]
GO

-- %%
/****** Object:  Table [dbo].[CATEGORYS]    Script Date: 4/19/2026 2:36:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CATEGORYS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CUSTOMERS]

-- %%
/****** Object:  Table [dbo].[CUSTOMERS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CUSTOMERS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](50) NULL,
	[PHONENUMBER] [nchar](11) NULL,
	[ADDRESS] [nvarchar](50) NULL,
	[BIRTHDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRODUCTS]

-- %%
/****** Object:  Table [dbo].[PRODUCTS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRODUCTS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](50) NULL,
	[BUYPRICE] [money] NULL,
	[SALEPRICE] [money] NULL,
	[QUANTITY] [float] NULL,
	[CATEGORYID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SALEORDERPRODUCTS]

-- %%
/****** Object:  Table [dbo].[SALEORDERPRODUCTS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SALEORDERPRODUCTS](
	[PRODUCTPRICE] [money] NULL,
	[PRODUCTQUANTITY] [float] NULL,
	[PRODUCTTOTALPRICE] [money] NULL,
	[ORDERID] [int] NOT NULL,
	[PRODUCTID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ORDERID] ASC,
	[PRODUCTID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SALEORDERS]

-- %%
/****** Object:  Table [dbo].[SALEORDERS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SALEORDERS](
	[ID] [int] NOT NULL,
	[DATEORDER] [datetime2](7) NULL,
	[CUSTOMERID] [int] NULL,
	[TOTALORDER] [money] NULL,
 CONSTRAINT [PK__SALEORDE__3214EC27E6633FFA] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[STOCKDETAILS]

-- %%
/****** Object:  Table [dbo].[STOCKDETAILS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[STOCKDETAILS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[STOCKID] [int] NULL,
	[TYPE] [int] NULL,
	[TOTAL] [money] NULL,
	[DATE] [datetime2](7) NULL,
	[ORDERID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[STOCKS]

-- %%
/****** Object:  Table [dbo].[STOCKS]    Script Date: 4/19/2026 2:36:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[STOCKS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](50) NULL,
	[TOTALMONEY] [money] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__PRODUCT__CATEGOR__3A81B327]

-- %%
ALTER TABLE [dbo].[PRODUCTS]  WITH CHECK ADD FOREIGN KEY([CATEGORYID])
REFERENCES [dbo].[CATEGORYS] ([ID])
GO

-- %% [markdown]
-- # [FK__SALEORDER__ORDER__4316F928]

-- %%
ALTER TABLE [dbo].[SALEORDERPRODUCTS]  WITH CHECK ADD  CONSTRAINT [FK__SALEORDER__ORDER__4316F928] FOREIGN KEY([ORDERID])
REFERENCES [dbo].[SALEORDERS] ([ID])
GO
ALTER TABLE [dbo].[SALEORDERPRODUCTS] CHECK CONSTRAINT [FK__SALEORDER__ORDER__4316F928]
GO

-- %% [markdown]
-- # [FK__SALEORDER__PRODU__440B1D61]

-- %%
ALTER TABLE [dbo].[SALEORDERPRODUCTS]  WITH CHECK ADD FOREIGN KEY([PRODUCTID])
REFERENCES [dbo].[PRODUCTS] ([ID])
GO

-- %% [markdown]
-- # [FK__SALEORDER__CUSTO__403A8C7D]

-- %%
ALTER TABLE [dbo].[SALEORDERS]  WITH CHECK ADD  CONSTRAINT [FK__SALEORDER__CUSTO__403A8C7D] FOREIGN KEY([CUSTOMERID])
REFERENCES [dbo].[CUSTOMERS] ([ID])
GO
ALTER TABLE [dbo].[SALEORDERS] CHECK CONSTRAINT [FK__SALEORDER__CUSTO__403A8C7D]
GO

-- %% [markdown]
-- # [FK__STOCKDETA__ORDER__49C3F6B7]

-- %%
ALTER TABLE [dbo].[STOCKDETAILS]  WITH CHECK ADD  CONSTRAINT [FK__STOCKDETA__ORDER__49C3F6B7] FOREIGN KEY([ORDERID])
REFERENCES [dbo].[SALEORDERS] ([ID])
GO
ALTER TABLE [dbo].[STOCKDETAILS] CHECK CONSTRAINT [FK__STOCKDETA__ORDER__49C3F6B7]
GO

-- %% [markdown]
-- # [FK__STOCKDETA__STOCK__48CFD27E]

-- %%
ALTER TABLE [dbo].[STOCKDETAILS]  WITH CHECK ADD FOREIGN KEY([STOCKID])
REFERENCES [dbo].[STOCKS] ([ID])
GO

-- %% [markdown]
-- # [SSTOREONLINE]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SSTOREONLINE] SET  READ_WRITE 
GO
